# %% [markdown]
# # mount google.colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd

# %cd /content/drive/MyDrive/Pointnet_Pointnet2_pytorch-master

# !pwd
# Out:
# /content
# /content/drive/MyDrive/Pointnet_Pointnet2_pytorch-master
# /content/drive/MyDrive/Pointnet_Pointnet2_pytorch-master

# %%
# !nvidia-smi
# Out:
# Mon Mar 13 11:36:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # pointnet2 train modelnet40

# %%
# !python train_classification.py --model pointnet2_cls_ssg --log_dir pointnet2_cls_ssg --process_data
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet2_cls_ssg', num_category=40, epoch=200, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet2_cls_ssg', decay_rate=0.0001, use_normals=False, process_data=True, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 9843
# Load processed data from data/modelnet40_normal_resampled/modelnet40_train_1024pts.dat...
# The size of test data is 2468
# Load processed data from data/modelnet40_normal_resampled/modelnet40_test_1024pts.dat...
# Use pretrain model
# Epoch 1 (52/200):
# 100% 410/410 [02:11<00:00,  3.13it/s]
# Train Instance Accuracy: 0.892988
# 100% 103/103 [00:22<00:00,  4.58it/s]
# Test Instance Accuracy: 0.893689, Class Accuracy: 0.858437
# Best Instance Accuracy: 0.893689, Class Accuracy: 0.858437
# Saving at log/classification/pointnet2_cls_ssg/checkpoints/best_model.pth
# Epoch 2 (53/200):
# 100% 410/410 [02:05<00:00,  3.28it/s]
# ...

# %% [markdown]
# # pointnet2 test modelnet40

# %%
# !python test_classification.py --log_dir pointnet2_cls_ssg
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=40, num_point=1024, log_dir='pointnet2_cls_ssg', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 2468
# 100% 103/103 [03:46<00:00,  2.20s/it]
# Test Instance Accuracy: 0.925566, Class Accuracy: 0.890099

# %% [markdown]
# # pointnet2 train modelnet10

# %%
# !python train_classification.py --model pointnet2_cls_ssg --log_dir pointnet2_cls_ssg_modelNet10 --process_data --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet2_cls_ssg', num_category=10, epoch=200, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet2_cls_ssg_modelNet10', decay_rate=0.0001, use_normals=False, process_data=True, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 3991
# Load processed data from data/modelnet40_normal_resampled/modelnet10_train_1024pts.dat...
# The size of test data is 908
# Load processed data from data/modelnet40_normal_resampled/modelnet10_test_1024pts.dat...
# No existing model, starting training from scratch...
# Epoch 1 (1/200):
# 100% 166/166 [00:52<00:00,  3.18it/s]
# Train Instance Accuracy: 0.697791
# 100% 38/38 [00:07<00:00,  4.82it/s]
# Test Instance Accuracy: 0.731140, Class Accuracy: 0.707676
# Best Instance Accuracy: 0.731140, Class Accuracy: 0.707676
# Saving at log/classification/pointnet2_cls_ssg_modelNet10/checkpoints/best_model.pth
# Epoch 2 (2/200):
# ...

# %% [markdown]
# # pointnet2 test modelnet10

# %%
# !python test_classification.py --log_dir pointnet2_cls_ssg_modelNet10 --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=10, num_point=1024, log_dir='pointnet2_cls_ssg_modelNet10', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 908
# 100% 38/38 [01:03<00:00,  1.67s/it]
# Test Instance Accuracy: 0.949561, Class Accuracy: 0.946042

# %% [markdown]
# # pointnet train modelnet10

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_modelNet10 --process_data --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=10, epoch=200, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet_cls_modelNet10', decay_rate=0.0001, use_normals=False, process_data=True, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 3991
# Load processed data from data/modelnet40_normal_resampled/modelnet10_train_1024pts.dat...
# The size of test data is 908
# Load processed data from data/modelnet40_normal_resampled/modelnet10_test_1024pts.dat...
# No existing model, starting training from scratch...
# Epoch 1 (1/200):
# 100% 166/166 [00:16<00:00, 10.24it/s]
# Train Instance Accuracy: 0.651857
# 100% 38/38 [00:00<00:00, 42.83it/s]
# Test Instance Accuracy: 0.603070, Class Accuracy: 0.549903
# Best Instance Accuracy: 0.603070, Class Accuracy: 0.549903
# Saving at log/classification/pointnet_cls_modelNet10/checkpoints/best_model.pth
# Epoch 2 (2/200):
# ...

# %% [markdown]
# # pointnet test modelnet10

# %%
# !python test_classification.py --log_dir pointnet_cls_modelNet10  --num_category 10
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=10, num_point=1024, log_dir='pointnet_cls_modelNet10', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 908
# 100% 38/38 [00:43<00:00,  1.16s/it]
# Test Instance Accuracy: 0.941886, Class Accuracy: 0.938863

# %% [markdown]
# # pointnet train modelnet40

# %%
# !python train_classification.py --model pointnet_cls --log_dir pointnet_cls_modelNet40 --process_data --num_category 40
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, model='pointnet_cls', num_category=40, epoch=200, learning_rate=0.001, num_point=1024, optimizer='Adam', log_dir='pointnet_cls_modelNet40', decay_rate=0.0001, use_normals=False, process_data=True, use_uniform_sample=False)
# Load dataset ...
# The size of train data is 9843
# Load processed data from data/modelnet40_normal_resampled/modelnet40_train_1024pts.dat...
# The size of test data is 2468
# Load processed data from data/modelnet40_normal_resampled/modelnet40_test_1024pts.dat...
# No existing model, starting training from scratch...
# Epoch 1 (1/200):
# 100% 410/410 [00:22<00:00, 18.32it/s]
# Train Instance Accuracy: 0.362398
# 100% 103/103 [00:02<00:00, 49.70it/s]
# Test Instance Accuracy: 0.380663, Class Accuracy: 0.273288
# Best Instance Accuracy: 0.380663, Class Accuracy: 0.273288
# Saving at log/classification/pointnet_cls_modelNet40/checkpoints/best_model.pth
# Epoch 2 (2/200):
# ...

# %% [markdown]
# # pointnet test modelnet40

# %%
# !python test_classification.py --log_dir pointnet_cls_modelNet40  --num_category 40
# Out:
# PARAMETER ...
# Namespace(use_cpu=False, gpu='0', batch_size=24, num_category=40, num_point=1024, log_dir='pointnet_cls_modelNet40', use_normals=False, use_uniform_sample=False, num_votes=3)
# Load dataset ...
# The size of test data is 2468
# 100% 103/103 [01:55<00:00,  1.12s/it]
# Test Instance Accuracy: 0.908414, Class Accuracy: 0.871637
